# %% [markdown]
# # Toy Datasets Visualization

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np, scipy.stats as st

# %%
from datasets import ToyDataset1, ToyDataset2, ToyDataset3, ToyDataset4

# %%
toy_dataset1 = ToyDataset1(num_samples=1000)
toy_dataset1_test = ToyDataset1(num_samples=200, xt_range=[-1.5, 1.5], noise_coef=0.5)
toy_dataset2 = ToyDataset2()
toy_dataset3 = ToyDataset3()
toy_dataset4 = ToyDataset4()

# %% [markdown]
# ## Toy Dataset 1 Plot

# %% [markdown]
# ### Train Set Plot

# %% [markdown]
# The dataset is considers the interval: $x \in [-1, -1]$

# %%
toy_dataset1.plot_dataset()

# %% [markdown]
# ### Test Dataset Plot
#
# Notice the $x$ values internval is now: $x \in [-1.5, 1.5]$

# %%
toy_dataset1_test.plot_dataset()

# %%
toy_dataset1_test.plot_dataset()
